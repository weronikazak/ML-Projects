# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# An **Exoplanet** is a planet that exists outside our solar system. Many exoplanets have been discovered over the years by Nasa’s Kepler telescope. Scientists discovered a very efficient way to study these occurrences; planets themselves **do not emit light, but the stars that orbit them do**. If you study and watch these stars over time there may be a regular dimming of their flux (The light intensity). That’s enough evidence to say that there is an orbiting body near the star. Further studies of the candidate system capture light at a different wavelength, could solidify the belief or confirm the existence of these orbiting bodies.

# %% [markdown]
# LABEL:
# - 1 - is an exoplanet
# - 2 - is a non-exoplanet star
#
# FLUX - the light intensity recorded for each star at a different point in time

# %%
df = pd.read_csv('exoTrain.csv')
df.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97  ...      -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56  ...     -71.69      13.31      13.31     -29.89
# 3   311.31  312.42  ...       5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57  ...    -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0      48.57      92.54      39.32      61.42       5.08     -39.54
# 1      -4.86       0.76     -11.70       6.46      16.00      19.93
# 2     -20.88       5.06     -11.80     -28.91     -70.02     -96.67
# 3      20.03     -12.67      -8.77     -17.31     -17.35      13.98
# 4    -443.76    -438.54    -399.71    -384.65    -411.79    -510.54
#
# [5 rows x 3198 columns]

# %%
from matplotlib import rcParams
rcParams["figure.figsize"] = 20, 4

df = df[df['LABEL'] == 2].drop(['LABEL'], axis=1).reset_index()

plt.plot(df.iloc[0,])
plt.plot(df.iloc[1,])
plt.plot(df.iloc[2,])
plt.plot(df.iloc[3,])
plt.show()

# %% [markdown]
# ## Normalizing

# %%
X = df.to_numpy()
max_X = np.max(X)
min_X = np.min(X)
print(max_X, min_X)
# Out:
# 150725.8 -118381.3

# %%
numerator = [x - min_X for x in np.nditer(X)]
denominator = max_X - min_X
multiplier = 0.95

# %%
X_norm = (numerator / denominator) * multiplier + 0.05
X_norm
# Out:
# array([0.46790884, 0.46791237, 0.4679159 , ..., 0.46924021, 0.46784953,
#        0.46799501])

# %%
X_norm.reshape(4, 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-092f4c405403> in <module>
# ----> 1 X_norm.reshape(4, 5)
#
# ValueError: cannot reshape array of size 118326 into shape (4,5)
