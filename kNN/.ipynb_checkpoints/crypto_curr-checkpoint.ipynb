# %%
import pandas as pd

df = pd.read_csv("data/crypto/LTC-USD.csv", names=['time', 'low', 'high', 'open', 'close', 'volume'])

df.head()
# Out:
#          time        low       high       open      close      volume
# 0  1528968660  96.580002  96.589996  96.589996  96.580002    9.647200
# 1  1528968720  96.449997  96.669998  96.589996  96.660004  314.387024
# 2  1528968780  96.470001  96.570000  96.570000  96.570000   77.129799
# 3  1528968840  96.449997  96.570000  96.570000  96.500000    7.216067
# 4  1528968900  96.279999  96.540001  96.500000  96.389999  524.539978

# %%
main_df = pd.DataFrame()

ratios = ["BTC-USD", "LTC-USD", "BCH-USD", "ETH-USD"]
for ratio in ratios:
    print(ratio)
    dataset = f'data/crypto/{ratio}.csv'
    df = pd.read_csv(dataset, names=['time', 'low', 'high', 'open', 'close', 'volume'])
    
    df.rename(columns={"close": f"{ratio}_close", "volume": f"{ratio}_volume"}, inplace=True)
    
    df.set_index('time', inplace=True)
    df = df[[f'{ratio}_close', f'{ratio}_volume']]
    
    if len(main_df) == 0:
        main_df = df
    else:
        main_df = main_df.join(df)
# Out:
# BTC-USD
# LTC-USD
# BCH-USD
# ETH-USD

# %%
main_df.head()
# Out:
#             BTC-USD_close  BTC-USD_volume  LTC-USD_close  LTC-USD_volume  \
# time
# 1528968660    6489.549805        0.587100      96.580002        9.647200
# 1528968720    6487.379883        7.706374      96.660004      314.387024
# 1528968780    6479.410156        3.088252      96.570000       77.129799
# 1528968840    6479.410156        1.404100      96.500000        7.216067
# 1528968900    6479.979980        0.753000      96.389999      524.539978
#
#             BCH-USD_close  BCH-USD_volume  ETH-USD_close  ETH-USD_volume
# time
# 1528968660     871.719971        5.675361            NaN             NaN
# 1528968720     870.859985       26.856577      486.01001       26.019083
# 1528968780     870.099976        1.124300      486.00000        8.449400
# 1528968840     870.789978        1.749862      485.75000       26.994646
# 1528968900     870.000000        1.680500      486.00000       77.355759

# %%
main_df.fillna(method='ffill', inplace=True)
main_df.dropna(inplace=True)
main_df.head()
# Out:
#             BTC-USD_close  BTC-USD_volume  LTC-USD_close  LTC-USD_volume  \
# time
# 1528968720    6487.379883        7.706374      96.660004      314.387024
# 1528968780    6479.410156        3.088252      96.570000       77.129799
# 1528968840    6479.410156        1.404100      96.500000        7.216067
# 1528968900    6479.979980        0.753000      96.389999      524.539978
# 1528968960    6480.000000        1.490900      96.519997       16.991997
#
#             BCH-USD_close  BCH-USD_volume  ETH-USD_close  ETH-USD_volume
# time
# 1528968720     870.859985       26.856577      486.01001       26.019083
# 1528968780     870.099976        1.124300      486.00000        8.449400
# 1528968840     870.789978        1.749862      485.75000       26.994646
# 1528968900     870.000000        1.680500      486.00000       77.355759
# 1528968960     869.989990        1.669014      486.00000        7.503300

# %%
SEQ_LEN = 60
FUTURE_PERIOD_PREDICT = 3
RATIO_TO_PREDICT = "LTC_USD"

def classify(current, future):
    if float(future) > float(current):
        return 1
    else:
        return 0

# %%
# main_df['future'] = main_df[f'{RATIO_TO_PREDICT}_close'].shift(-FUTURE_PERIOD_PREDICT)

# %%
# main_df['target'] = list(map(classify, main_df[f'{RATIO_TO_PREDICT}_close'], main_df['future']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# R:\Work\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LTC_USD_close'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-68044e190de8> in <module>
# ----> 1 main_df['target'] = list(map(classify, main_df[f'{RATIO_TO_PREDICT}_close'], main_df['future']))
#
# R:\Work\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# R:\Work\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LTC_USD_close'
