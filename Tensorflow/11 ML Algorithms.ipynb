# %% [markdown]
# # 1. Linear Regression
#
# - when there's a single input variable (x), the equation is referred to as **simple linear regression**.
#
# - when there is more than one input variable, the equation is referred to as **multiple linear regression**.

# %% [markdown]
# ##### The Equation:
#
# $$
# y = b_0 + b_1x
# $$
#
# - $x$ - input variable
# - $y$ - output variable
# - $b_0$ and $b_1$ - coefficients

# %% [markdown]
# The line of best fit is found by minimizing the squared distances between the points and the line of best fit and this is know na **minimizing the um of squared residuals**.
#
# A **residual** is simply equal to the predicted value minus the actual value.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Logistic Regression
#
# Used to predict a binary outcome (1/0, Yes/No, True/False, Dog/Cat)
#
# - can be thought of as a special case of linear regression when the outcome variable is categorical, where we are using the log of odds as a dependent variable.
#
# - predicts the probability of occurence of an event by fitting data to a logit function.

# %% [markdown]
# ###### The equation:
#
# $$
# P(X) = \frac{e^{(b_0 + b_1x)}}{e^{(b_0 + b_1x)} + 1}
# $$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. K-Nearest Neighbours
#
# Supervised machine learning algorithm.
#
# Used to solve both classification and regression problems.
#
# It works by finding the distances between the new data point added and the points already existed in the two separate classes.
#
# whichtever classgot the highest votes, the new data point belongs to that class.

# %% [markdown]
# ###### The Equation:
#
# $$
# \text{Euclidean Distance}(x, x_i) = \sqrt{\sum{(x_j - x_{ij})^2}}
# $$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Support Vector Machines
#
# Supervised machine learning algorithm.
#
# Used for classification as well as regression. Mostly used in the primary tho.
#
# As SVM will find a hyperplane or a boundary between the two classes of data that maximizes.
#
# There are other planes as well, which can separate the two classes, but only the SVM plane can maximize the margin between the classes.

# %% [markdown]
# ###### The equation:
#
# $$
# b_0 + (b_1 * x_1) + (b_2 * b_2) = 0
# $$
#
# - $b_1$ and $b_2$ determines the slope of the line and $b_0$ (intercept) found by the learning algorithm.
#
# - $x_1$ and $x_2$ are the two input variables.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Decision Trees:
#
# Decision Trees algorithms are referred to as CART ot Classification and REgression Tress.
#
# It is a flowchart like a tree structure, where each internal node denotes a test on an attribute, each branch represents an outcome of the test, and each leaf node (terminal node) holds a class label.
#
# A Gini core gives an idea of how good a split is by how mixed the response clases are in the group created by the split.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Random Forest
#
# Ensemble learning technique that builds off of decision trees.
#
# - Random Forests involve creating multiple decision trees using bootstrapped datasets of the original data and randomly selecting a subset of variables at each step of the decision tree.
#
# - The model then selects the mode of all of the predictions of each decision tree (bagging)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. AdaBoost
#
# Adaptive boost is also an ensemble algorithm that leverages bagging and boosting methods to develop an enhanced predictor.
#
# - AdaBoot creates a forest of stumps rether than trees. A stump is a tree that i made of only one node and two layers.
#
# - AdaBoost takes a more iterative approach in the sense that it seeks to iteratively improve from  the mistakes that the previous stump(s) made.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. Gradient Boost
#
# - Unlinke AdaBoost which builds stumps, Gradient Boost builds trees with usually 8-32 leaves.
#
# - Gradient Boost views boosting problem as an optimization problem, where it uses a loss function and tries to minimize the error. This is why it's called Gradient Boost, as it's inspired by gradient descent.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # XG Boost
#
# XG Boost is one of the most popular and widely used algorithms today because it's simply so powerful.
#
# - similar to Gradient Boost, but has a few extra features that make it that much stronger
#
# - Newton Boosting - provides a direct route to the minima than gradient descent, making it much faster.
#
# - An extra randomization parameter - reduces the correlation between trees, ultimately improving the strength of the ensemble.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 10. Light GBM
#
# Another type of boosting algorithm that has shown to be faster and sometimes more accurate than XGBoost.
#
# It ues a technique called Gradient-based One-side sampling (GOSS) to filter out the data instances tofind a split value.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Naive Bayes
#
# Classification algorithm used for binary and muticlass classification problems. It is used when the output variable is dicrete.
#
# - As the name specifie, this algorithm is entirely used on Bayes's theorem. Bayes' theorem says we can calculate the probability of a piece of data belonging to a given class if prior knowledge i given.

# %% [markdown]
# https://medium.com/codex/11-ml-algorithms-you-should-know-in-2021-8fecbd3a2a1a

# %% [markdown]
# ![image.png](attachment:image.png)
