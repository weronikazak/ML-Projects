# %%
# The basic CNN structure is as follows: 
# Convolution -> Pooling -> Convolution -> Pooling -> Fully Connected Layer -> Output

# Convolution is the act of taking the original data, and creating feature maps from it.
# Pooling is down-sampling, most often in the form of "max-pooling," where we select a region,
# and then take the maximum value in that region, and that becomes the new value for the entire region.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import pickle
import numpy as np

pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle", "rb")
y = pickle.load(pickle_in)

y = np.array(y)

# %%
from tensorflow.keras.callbacks import TensorBoard
import datetime, os

X = X/255.0

# %%
import time

dense_layers = [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-lay-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            print(NAME)
            
            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation("relu"))
            model.add(MaxPooling2D(pool_size=(2, 2)))
            
            for i in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation("relu"))
                model.add(MaxPooling2D(pool_size=(2, 2)))
            
            model.add(Flatten())
            
            for i in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation("relu"))
            
            model.add(Dense(1))
            model.add(Activation('sigmoid'))
            
            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME), profile_batch = 100000000)

            model.compile(loss="binary_crossentropy",
                          optimizer="adam",
                          metrics=['accuracy'])
            
            model.fit(X, y, validation_split=0.3, callbacks=[tensorboard])
# Out:
# 1-conv-32-lay-0-dense-1582581636
# WARNING:tensorflow:From R:\Work\Anaconda\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From R:\Work\Anaconda\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 90s 5ms/sample - loss: 0.6289 - acc: 0.6508 - val_loss: 0.5626 - val_acc: 0.7296
# 2-conv-32-lay-0-dense-1582581730
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 149s 9ms/sample - loss: 0.6061 - acc: 0.6617 - val_loss: 0.5210 - val_acc: 0.7496
# 3-conv-32-lay-0-dense-1582581879
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 165s 9ms/sample - loss: 0.6342 - acc: 0.6294 - val_loss: 0.5485 - val_acc: 0.7286
# 1-conv-64-lay-0-dense-1582582045
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 152s 9ms/sample - loss: 0.6111 - acc: 0.6668 - val_loss: 0.5488 - val_acc: 0.7310
# 2-conv-64-lay-0-dense-1582582198
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 317s 18ms/sample - loss: 0.6479 - acc: 0.6153 - val_loss: 0.5927 - val_acc: 0.6801
# 3-conv-64-lay-0-dense-1582582516
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 336s 19ms/sample - loss: 0.6418 - acc: 0.6228 - val_loss: 0.5398 - val_acc: 0.7328
# 1-conv-128-lay-0-dense-1582582853
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 279s 16ms/sample - loss: 0.6275 - acc: 0.6653 - val_loss: 0.5453 - val_acc: 0.7368
# 2-conv-128-lay-0-dense-1582583133
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 512s 29ms/sample - loss: 0.6683 - acc: 0.5881 - val_loss: 0.6365 - val_acc: 0.6522
# 3-conv-128-lay-0-dense-1582583647
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 559s 32ms/sample - loss: 0.6573 - acc: 0.5978 - val_loss: 0.5646 - val_acc: 0.7137
# 1-conv-32-lay-1-dense-1582584207
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 78s 4ms/sample - loss: 0.6166 - acc: 0.6671 - val_loss: 0.5440 - val_acc: 0.7402
# 2-conv-32-lay-1-dense-1582584286
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 112s 6ms/sample - loss: 0.6166 - acc: 0.6465 - val_loss: 0.5367 - val_acc: 0.7265
# 3-conv-32-lay-1-dense-1582584400
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 121s 7ms/sample - loss: 0.6321 - acc: 0.6299 - val_loss: 0.5343 - val_acc: 0.7369
# 1-conv-64-lay-1-dense-1582584522
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 158s 9ms/sample - loss: 0.6176 - acc: 0.6683 - val_loss: 0.5548 - val_acc: 0.7194
# 2-conv-64-lay-1-dense-1582584682
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 238s 14ms/sample - loss: 0.6648 - acc: 0.5968 - val_loss: 0.6049 - val_acc: 0.6710
# 3-conv-64-lay-1-dense-1582584921
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 252s 14ms/sample - loss: 0.6510 - acc: 0.6100 - val_loss: 0.5743 - val_acc: 0.7003
# 1-conv-128-lay-1-dense-1582585174
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 361s 21ms/sample - loss: 0.7547 - acc: 0.4998 - val_loss: 0.6914 - val_acc: 0.5216
# 2-conv-128-lay-1-dense-1582585539
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 523s 30ms/sample - loss: 0.6620 - acc: 0.6033 - val_loss: 0.6062 - val_acc: 0.6825
# 3-conv-128-lay-1-dense-1582586064
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 568s 33ms/sample - loss: 0.6410 - acc: 0.6221 - val_loss: 0.5380 - val_acc: 0.7289
# 1-conv-32-lay-2-dense-1582586634
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 77s 4ms/sample - loss: 0.6275 - acc: 0.6406 - val_loss: 0.5618 - val_acc: 0.7127
# 2-conv-32-lay-2-dense-1582586713
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 110s 6ms/sample - loss: 0.6233 - acc: 0.6432 - val_loss: 0.5333 - val_acc: 0.7365
# 3-conv-32-lay-2-dense-1582586825
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 119s 7ms/sample - loss: 0.6794 - acc: 0.5557 - val_loss: 0.6285 - val_acc: 0.6696
# 1-conv-64-lay-2-dense-1582586947
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 160s 9ms/sample - loss: 0.6358 - acc: 0.6445 - val_loss: 0.6007 - val_acc: 0.6801
# 2-conv-64-lay-2-dense-1582587109
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 239s 14ms/sample - loss: 0.6535 - acc: 0.6042 - val_loss: 0.5781 - val_acc: 0.6935
# 3-conv-64-lay-2-dense-1582587351
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 252s 14ms/sample - loss: 0.6762 - acc: 0.5644 - val_loss: 0.6073 - val_acc: 0.6778
# 1-conv-128-lay-2-dense-1582587605
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 356s 20ms/sample - loss: 0.6411 - acc: 0.6563 - val_loss: 0.5642 - val_acc: 0.7159
# 2-conv-128-lay-2-dense-1582587965
# Train on 17462 samples, validate on 7484 samples
# 17462/17462 [==============================] - 550s 31ms/sample - loss: 0.6708 - acc: 0.5901 - val_loss: 0.6081 - val_acc: 0.6721
# 3-conv-128-lay-2-dense-1582588517
# Train on 17462 samples, validate on 7484 samples
# 16800/17462 [===========================>..] - ETA: 20s - loss: 0.6666 - acc: 0.5871
