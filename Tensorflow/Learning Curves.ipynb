# %% [markdown]
# **Optimization Learning Curves** - learning curves on the metric by which the parameters of the model are being optimized, e.g. loss
#
# **Performance Learning Curves** - learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy

# %% [markdown]
# ## Underfit
#
# Underfitting refers to a model that cannot learn the training dataset.
#
# An underfit model can be identified from the learning curve of the training loss only.

# %% [markdown]
# A flat line or noisy values of relatively high loss, indicating the model was unable to learn dataset at all.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# An underfit model may also be identified by a training loss that is decreasing and continues to decrease at the end of the plot.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Overfit
#
# Overfitting refers to a model that has learned the training dataset too well, including the statistical noise or random fluctuations in the training dataset.
#
# This often occurs if the model has more capacity than is required for the problem, and, in turn, too mucj flexibity. It can also occur if the model is trained for too long.
#
# A plot of learning curves show overfitting if:
#
# - The plot of training loss continues to decrease with experience.
#
# - The plot of validation loss decrease to a point and begins increasing again.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Good Fit Learning Curves
#
# A good fit is identified by a training and validation loss that decreases to a point of stability with a minimal gap between the two final loss values.
#
# The loss of the model will almost always be lower on the training dataset than the validation dataset. This means that we should expect some gap between the train and validation loss learning curves. This gap is referred to as the "generalization gap".
#
# A plot of learning curves shows a good fit is:
# - The plot of training loss decreases to a point of stability
#
# - The plot of validation loss decreases to a point of stability and has a small gap with the trainng loss

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Unrepresentative Datasets
#
# An unrepresentative dataset means a dataset that may not capture the statistical characteristics relative to another dataset drawn from the same domain, such as between a train and a validation dataset.
#
# This can commonly occur if the number of samples in a dataset is to small, relative to another dataset.

# %% [markdown]
# #### Unrepresentative Train Dataset
#
# An unrepresentative training dataset means that the training dataset doen't provide sufficient information to learn the problem, relative to the validation dataset used to evaluate it.
#
# This may occur when training dataset has too few examples as compared to the valdidation dataset.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Unrepresentative Validation Dataset
#
# The validation dataset doesn't provide sufficient information to evaluate the ability of the model to generalize.
#
# This may occur, if the validation dataset has too few examples as compared to the training dataset.

# %% [markdown]
# This case can be identified by a learning curve for training loss that looks like a good fit and a learning curve for validation loss that shows noisy movements around the training loss.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It may also be identified by a validation loss that is lower than the training loss. In this case it indicates that the validation dataset may be easier for the model to predict than the training dataset.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/
