# %%
import tensorflow.compat.v1 as tf
import numpy as np
import os, sys

DATA_SIZE = 100
SAVE_PATH = "./save"
EPOCHS = 1000
LEARNING_RATE = 0.01
MODEL_NAME = "test"

if not os.path.exists(SAVE_PATH):
    os.mkdir(SAVE_PATH)

# %%
data = (np.random.rand(DATA_SIZE, 2), np.random.rand(DATA_SIZE, 1))
test = (np.random.rand(DATA_SIZE // 8, 2), np.random.rand(DATA_SIZE // 8, 1))

# %%
tf.disable_eager_execution()
tf.reset_default_graph()

x = tf.placeholder(tf.float32, shape=[None, 2], name="inputs")
y = tf.placeholder(tf.float32, shape=[None, 1], name="targets")

# %%
net = tf.layers.dense(x, 16, name="inputs")
net = tf.layers.dense(net, 16, activation=tf.nn.relu)
pred = tf.layers.dense(net, 1, activation=tf.nn.sigmoid, name="prediction")
# Out:
# R:\Work\Anacond\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# R:\Work\Anacond\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '

# %%
loss = tf.reduce_mean(tf.squared_difference(y, pred), name="loss")
train_step = tf.train.AdamOptimizer(LEARNING_RATE).minimize(loss)

checkpoint = tf.train.latest_checkpoint(SAVE_PATH)
should_train = checkpoint == None

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    if should_train:
        print("Training")
        saver = tf.train.Saver()
        for epoch in range(EPOCHS):
            _, curr_loss = sess.run([train_step, loss], feed_dict={x: data[0], y: data[1]})
            print(f"EPOCH = {epoch}, LOSS={curr_loss:0.4f}")
            path = saver.save(sess, SAVE_PATH + "/" + MODEL_NAME + ".ckpt")
            print(f"Saved at {path}")
    else:
        print("Restoring")
        graph = tf.get_default_graph()
        saver = tf.train.import_meta_graph(checkpoint + ".meta")
        saver.restore(sess, checkpoint)

        loss = graph.get_tensor_by_name("loss:0")

        test_loss = sess.run(loss, feed_dict={"inputs:0":test[0], "targets:0":test[1]})
        print(sess.run(pred, feed_dict={"inputs:0":np.random.rand(10, 2)}))
        print(f"TEST LOSS = {test_loss:0.4f}")
# Out:
# Training
# EPOCH = 0, LOSS=0.0853
# Saved at ./save/test.ckpt
# EPOCH = 1, LOSS=0.0808
# Saved at ./save/test.ckpt
# EPOCH = 2, LOSS=0.0827
# Saved at ./save/test.ckpt
# EPOCH = 3, LOSS=0.0826
# Saved at ./save/test.ckpt
# EPOCH = 4, LOSS=0.0811
# Saved at ./save/test.ckpt
# EPOCH = 5, LOSS=0.0803
# Saved at ./save/test.ckpt
# EPOCH = 6, LOSS=0.0804
# Saved at ./save/test.ckpt
# EPOCH = 7, LOSS=0.0807
# Saved at ./save/test.ckpt
# EPOCH = 8, LOSS=0.0807
# Saved at ./save/test.ckpt
# EPOCH = 9, LOSS=0.0803
# Saved at ./save/test.ckpt
# EPOCH = 10, LOSS=0.0799
# Saved at ./save/test.ckpt
# EPOCH = 11, LOSS=0.0798
# Saved at ./save/test.ckpt
# EPOCH = 12, LOSS=0.0799
# Saved at ./save/test.ckpt
# EPOCH = 13, LOSS=0.0799
# Saved at ./save/test.ckpt
# EPOCH = 14, LOSS=0.0798
# Saved at ./save/test.ckpt
# EPOCH = 15, LOSS=0.0796
# Saved at ./save/test.ckpt
# EPOCH = 16, LOSS=0.0795
# Saved at ./save/test.ckpt
# EPOCH = 17, LOSS=0.0794
# Saved at ./save/test.ckpt
# EPOCH = 18, LOSS=0.0794
# Saved at ./save/test.ckpt
# EPOCH = 19, LOSS=0.0792
# Saved at ./save/test.ckpt
# EPOCH = 20, LOSS=0.0790
# Saved at ./save/test.ckpt
# EPOCH = 21, LOSS=0.0789
# Saved at ./save/test.ckpt
# EPOCH = 22, LOSS=0.0789
# Saved at ./save/test.ckpt
# EPOCH = 23, LOSS=0.0788
# Saved at ./save/test.ckpt
# EPOCH = 24, LOSS=0.0787
# Saved at ./save/test.ckpt
# EPOCH = 25, LOSS=0.0786
# Saved at ./save/test.ckpt
# EPOCH = 26, LOSS=0.0785
# Saved at ./save/test.ckpt
# EPOCH = 27, LOSS=0.0784
# Saved at ./save/test.ckpt
# EPOCH = 28, LOSS=0.0782
# Saved at ./save/test.ckpt
# EPOCH = 29, LOSS=0.0781
# Saved at ./save/test.ckpt
# EPOCH = 30, LOSS=0.0781
# Saved at ./save/test.ckpt
# EPOCH = 31, LOSS=0.0780
# Saved at ./save/test.ckpt
# EPOCH = 32, LOSS=0.0778
# Saved at ./save/test.ckpt
# EPOCH = 33, LOSS=0.0777
# Saved at ./save/test.ckpt
# EPOCH = 34, LOSS=0.0776
# Saved at ./save/test.ckpt
# EPOCH = 35, LOSS=0.0775
# Saved at ./save/test.ckpt
# EPOCH = 36, LOSS=0.0774
# Saved at ./save/test.ckpt
# EPOCH = 37, LOSS=0.0772
# Saved at ./save/test.ckpt
# EPOCH = 38, LOSS=0.0771
# Saved at ./save/test.ckpt
# EPOCH = 39, LOSS=0.0770
# Saved at ./save/test.ckpt
# EPOCH = 40, LOSS=0.0769
# Saved at ./save/test.ckpt
# EPOCH = 41, LOSS=0.0767
# Saved at ./save/test.ckpt
# EPOCH = 42, LOSS=0.0766
# Saved at ./save/test.ckpt
# EPOCH = 43, LOSS=0.0765
# Saved at ./save/test.ckpt
# EPOCH = 44, LOSS=0.0763
# Saved at ./save/test.ckpt
# EPOCH = 45, LOSS=0.0762
# Saved at ./save/test.ckpt
# EPOCH = 46, LOSS=0.0760
# Saved at ./save/test.ckpt
# EPOCH = 47, LOSS=0.0759
# Saved at ./save/test.ckpt
# EPOCH = 48, LOSS=0.0757
# Saved at ./save/test.ckpt
# EPOCH = 49, LOSS=0.0756
# Saved at ./save/test.ckpt
# EPOCH = 50, LOSS=0.0754
# Saved at ./save/test.ckpt
# EPOCH = 51, LOSS=0.0753
# Saved at ./save/test.ckpt
# EPOCH = 52, LOSS=0.0751
# Saved at ./save/test.ckpt
# EPOCH = 53, LOSS=0.0750
# Saved at ./save/test.ckpt
# EPOCH = 54, LOSS=0.0748
# Saved at ./save/test.ckpt
# EPOCH = 55, LOSS=0.0747
# Saved at ./save/test.ckpt
# EPOCH = 56, LOSS=0.0745
# Saved at ./save/test.ckpt
# EPOCH = 57, LOSS=0.0744
# Saved at ./save/test.ckpt
# EPOCH = 58, LOSS=0.0742
# Saved at ./save/test.ckpt
# EPOCH = 59, LOSS=0.0740
# Saved at ./save/test.ckpt
# EPOCH = 60, LOSS=0.0739
# Saved at ./save/test.ckpt
# EPOCH = 61, LOSS=0.0737
# Saved at ./save/test.ckpt
# EPOCH = 62, LOSS=0.0735
# Saved at ./save/test.ckpt
# EPOCH = 63, LOSS=0.0734
# Saved at ./save/test.ckpt
# EPOCH = 64, LOSS=0.0732
# Saved at ./save/test.ckpt
# EPOCH = 65, LOSS=0.0730
# Saved at ./save/test.ckpt
# EPOCH = 66, LOSS=0.0728
# Saved at ./save/test.ckpt
# EPOCH = 67, LOSS=0.0727
# Saved at ./save/test.ckpt
# EPOCH = 68, LOSS=0.0725
# Saved at ./save/test.ckpt
# EPOCH = 69, LOSS=0.0723
# Saved at ./save/test.ckpt
# EPOCH = 70, LOSS=0.0721
# Saved at ./save/test.ckpt
# EPOCH = 71, LOSS=0.0719
# Saved at ./save/test.ckpt
# EPOCH = 72, LOSS=0.0717
# Saved at ./save/test.ckpt
# EPOCH = 73, LOSS=0.0715
# Saved at ./save/test.ckpt
# EPOCH = 74, LOSS=0.0714
# Saved at ./save/test.ckpt
# EPOCH = 75, LOSS=0.0712
# Saved at ./save/test.ckpt
# EPOCH = 76, LOSS=0.0710
# Saved at ./save/test.ckpt
# EPOCH = 77, LOSS=0.0708
# Saved at ./save/test.ckpt
# EPOCH = 78, LOSS=0.0706
# Saved at ./save/test.ckpt
# EPOCH = 79, LOSS=0.0704
# Saved at ./save/test.ckpt
# EPOCH = 80, LOSS=0.0702
# Saved at ./save/test.ckpt
# EPOCH = 81, LOSS=0.0701
# Saved at ./save/test.ckpt
# EPOCH = 82, LOSS=0.0699
# Saved at ./save/test.ckpt
# EPOCH = 83, LOSS=0.0697
# Saved at ./save/test.ckpt
# EPOCH = 84, LOSS=0.0695
# Saved at ./save/test.ckpt
# EPOCH = 85, LOSS=0.0693
# Saved at ./save/test.ckpt
# EPOCH = 86, LOSS=0.0691
# Saved at ./save/test.ckpt
# EPOCH = 87, LOSS=0.0690
# Saved at ./save/test.ckpt
# EPOCH = 88, LOSS=0.0688
# Saved at ./save/test.ckpt
# EPOCH = 89, LOSS=0.0686
# Saved at ./save/test.ckpt
# EPOCH = 90, LOSS=0.0685
# Saved at ./save/test.ckpt
# EPOCH = 91, LOSS=0.0683
# Saved at ./save/test.ckpt
# EPOCH = 92, LOSS=0.0682
# Saved at ./save/test.ckpt
# EPOCH = 93, LOSS=0.0680
# Saved at ./save/test.ckpt
# EPOCH = 94, LOSS=0.0679
# Saved at ./save/test.ckpt
# EPOCH = 95, LOSS=0.0677
# Saved at ./save/test.ckpt
# EPOCH = 96, LOSS=0.0676
# Saved at ./save/test.ckpt
# EPOCH = 97, LOSS=0.0674
# Saved at ./save/test.ckpt
# EPOCH = 98, LOSS=0.0673
# Saved at ./save/test.ckpt
# EPOCH = 99, LOSS=0.0672
# Saved at ./save/test.ckpt
# EPOCH = 100, LOSS=0.0670
# Saved at ./save/test.ckpt
# EPOCH = 101, LOSS=0.0669
# Saved at ./save/test.ckpt
# EPOCH = 102, LOSS=0.0667
# Saved at ./save/test.ckpt
# EPOCH = 103, LOSS=0.0667
# Saved at ./save/test.ckpt
# EPOCH = 104, LOSS=0.0665
# Saved at ./save/test.ckpt
# EPOCH = 105, LOSS=0.0664
# Saved at ./save/test.ckpt
# EPOCH = 106, LOSS=0.0663
# Saved at ./save/test.ckpt
# EPOCH = 107, LOSS=0.0661
# Saved at ./save/test.ckpt
# EPOCH = 108, LOSS=0.0660
# Saved at ./save/test.ckpt
# EPOCH = 109, LOSS=0.0659
# Saved at ./save/test.ckpt
# EPOCH = 110, LOSS=0.0657
# Saved at ./save/test.ckpt
# EPOCH = 111, LOSS=0.0656
# Saved at ./save/test.ckpt
# EPOCH = 112, LOSS=0.0654
# Saved at ./save/test.ckpt
# EPOCH = 113, LOSS=0.0653
# Saved at ./save/test.ckpt
# EPOCH = 114, LOSS=0.0651
# Saved at ./save/test.ckpt
# EPOCH = 115, LOSS=0.0650
# Saved at ./save/test.ckpt
# EPOCH = 116, LOSS=0.0649
# Saved at ./save/test.ckpt
# EPOCH = 117, LOSS=0.0648
# Saved at ./save/test.ckpt
# EPOCH = 118, LOSS=0.0647
# Saved at ./save/test.ckpt
# EPOCH = 119, LOSS=0.0645
# Saved at ./save/test.ckpt
# EPOCH = 120, LOSS=0.0644
# Saved at ./save/test.ckpt
# EPOCH = 121, LOSS=0.0643
# Saved at ./save/test.ckpt
# EPOCH = 122, LOSS=0.0641
# Saved at ./save/test.ckpt
# EPOCH = 123, LOSS=0.0641
# Saved at ./save/test.ckpt
# EPOCH = 124, LOSS=0.0639
# Saved at ./save/test.ckpt
# EPOCH = 125, LOSS=0.0639
# Saved at ./save/test.ckpt
# EPOCH = 126, LOSS=0.0638
# Saved at ./save/test.ckpt
# EPOCH = 127, LOSS=0.0636
# Saved at ./save/test.ckpt
# EPOCH = 128, LOSS=0.0635
# Saved at ./save/test.ckpt
# EPOCH = 129, LOSS=0.0635
# Saved at ./save/test.ckpt
# EPOCH = 130, LOSS=0.0634
# Saved at ./save/test.ckpt
# EPOCH = 131, LOSS=0.0633
# Saved at ./save/test.ckpt
# EPOCH = 132, LOSS=0.0632
# Saved at ./save/test.ckpt
# EPOCH = 133, LOSS=0.0631
# Saved at ./save/test.ckpt
# EPOCH = 134, LOSS=0.0631
# Saved at ./save/test.ckpt
# EPOCH = 135, LOSS=0.0630
# Saved at ./save/test.ckpt
# EPOCH = 136, LOSS=0.0629
# Saved at ./save/test.ckpt
# EPOCH = 137, LOSS=0.0629
# Saved at ./save/test.ckpt
# EPOCH = 138, LOSS=0.0628
# Saved at ./save/test.ckpt
# EPOCH = 139, LOSS=0.0627
# Saved at ./save/test.ckpt
# EPOCH = 140, LOSS=0.0627
# Saved at ./save/test.ckpt
# EPOCH = 141, LOSS=0.0626
# Saved at ./save/test.ckpt
# EPOCH = 142, LOSS=0.0626
# Saved at ./save/test.ckpt
# EPOCH = 143, LOSS=0.0625
# Saved at ./save/test.ckpt
# EPOCH = 144, LOSS=0.0625
# Saved at ./save/test.ckpt
# EPOCH = 145, LOSS=0.0625
# Saved at ./save/test.ckpt
# EPOCH = 146, LOSS=0.0625
# Saved at ./save/test.ckpt
# EPOCH = 147, LOSS=0.0624
# Saved at ./save/test.ckpt
# EPOCH = 148, LOSS=0.0624
# Saved at ./save/test.ckpt
# EPOCH = 149, LOSS=0.0623
# Saved at ./save/test.ckpt
# EPOCH = 150, LOSS=0.0624
# Saved at ./save/test.ckpt
# EPOCH = 151, LOSS=0.0623
# Saved at ./save/test.ckpt
# EPOCH = 152, LOSS=0.0623
# Saved at ./save/test.ckpt
# EPOCH = 153, LOSS=0.0622
# Saved at ./save/test.ckpt
# EPOCH = 154, LOSS=0.0623
# Saved at ./save/test.ckpt
# EPOCH = 155, LOSS=0.0622
# Saved at ./save/test.ckpt
# EPOCH = 156, LOSS=0.0621
# Saved at ./save/test.ckpt
# EPOCH = 157, LOSS=0.0622
# Saved at ./save/test.ckpt
# EPOCH = 158, LOSS=0.0621
# Saved at ./save/test.ckpt
# EPOCH = 159, LOSS=0.0621
# Saved at ./save/test.ckpt
# EPOCH = 160, LOSS=0.0621
# Saved at ./save/test.ckpt
# EPOCH = 161, LOSS=0.0621
# Saved at ./save/test.ckpt
# EPOCH = 162, LOSS=0.0621
# Saved at ./save/test.ckpt
# EPOCH = 163, LOSS=0.0621
# Saved at ./save/test.ckpt
# EPOCH = 164, LOSS=0.0621
# Saved at ./save/test.ckpt
# EPOCH = 165, LOSS=0.0620
# Saved at ./save/test.ckpt
# EPOCH = 166, LOSS=0.0620
# Saved at ./save/test.ckpt
# EPOCH = 167, LOSS=0.0619
# Saved at ./save/test.ckpt
# EPOCH = 168, LOSS=0.0619
# Saved at ./save/test.ckpt
# EPOCH = 169, LOSS=0.0619
# Saved at ./save/test.ckpt
# EPOCH = 170, LOSS=0.0619
# Saved at ./save/test.ckpt
# EPOCH = 171, LOSS=0.0619
# Saved at ./save/test.ckpt
# EPOCH = 172, LOSS=0.0619
# Saved at ./save/test.ckpt
# EPOCH = 173, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 174, LOSS=0.0619
# Saved at ./save/test.ckpt
# EPOCH = 175, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 176, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 177, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 178, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 179, LOSS=0.0617
# Saved at ./save/test.ckpt
# EPOCH = 180, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 181, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 182, LOSS=0.0617
# Saved at ./save/test.ckpt
# EPOCH = 183, LOSS=0.0617
# Saved at ./save/test.ckpt
# EPOCH = 184, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 185, LOSS=0.0618
# Saved at ./save/test.ckpt
# EPOCH = 186, LOSS=0.0617
# Saved at ./save/test.ckpt
# EPOCH = 187, LOSS=0.0617
# Saved at ./save/test.ckpt
# EPOCH = 188, LOSS=0.0617
# Saved at ./save/test.ckpt
# EPOCH = 189, LOSS=0.0617
# Saved at ./save/test.ckpt
# EPOCH = 190, LOSS=0.0617
# Saved at ./save/test.ckpt
# EPOCH = 191, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 192, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 193, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 194, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 195, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 196, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 197, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 198, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 199, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 200, LOSS=0.0616
# Saved at ./save/test.ckpt
# EPOCH = 201, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 202, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 203, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 204, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 205, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 206, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 207, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 208, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 209, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 210, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 211, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 212, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 213, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 214, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 215, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 216, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 217, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 218, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 219, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 220, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 221, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 222, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 223, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 224, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 225, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 226, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 227, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 228, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 229, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 230, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 231, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 232, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 233, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 234, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 235, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 236, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 237, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 238, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 239, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 240, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 241, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 242, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 243, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 244, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 245, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 246, LOSS=0.0615
# Saved at ./save/test.ckpt
# EPOCH = 247, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 248, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 249, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 250, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 251, LOSS=0.0613
# Saved at ./save/test.ckpt
# EPOCH = 252, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 253, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 254, LOSS=0.0613
# Saved at ./save/test.ckpt
# EPOCH = 255, LOSS=0.0613
# Saved at ./save/test.ckpt
# EPOCH = 256, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 257, LOSS=0.0613
# Saved at ./save/test.ckpt
# EPOCH = 258, LOSS=0.0613
# Saved at ./save/test.ckpt
# EPOCH = 259, LOSS=0.0614
# Saved at ./save/test.ckpt
# EPOCH = 260, LOSS=0.0613
# Saved at ./save/test.ckpt
# EPOCH = 261, LOSS=0.0613
# Saved at ./save/test.ckpt
# EPOCH = 262, LOSS=0.0613
# Saved at ./save/test.ckpt
# EPOCH = 263, LOSS=0.0612
# Saved at ./save/test.ckpt
# EPOCH = 264, LOSS=0.0612
# Saved at ./save/test.ckpt
# EPOCH = 265, LOSS=0.0612
# Saved at ./save/test.ckpt
# EPOCH = 266, LOSS=0.0612
# Saved at ./save/test.ckpt
# EPOCH = 267, LOSS=0.0612
# Saved at ./save/test.ckpt
# EPOCH = 268, LOSS=0.0612
# Saved at ./save/test.ckpt
# EPOCH = 269, LOSS=0.0612
# Saved at ./save/test.ckpt
# EPOCH = 270, LOSS=0.0611
# Saved at ./save/test.ckpt
# EPOCH = 271, LOSS=0.0611
# Saved at ./save/test.ckpt
# EPOCH = 272, LOSS=0.0611
# Saved at ./save/test.ckpt
# EPOCH = 273, LOSS=0.0611
# Saved at ./save/test.ckpt
# EPOCH = 274, LOSS=0.0611
# Saved at ./save/test.ckpt
# EPOCH = 275, LOSS=0.0611
# Saved at ./save/test.ckpt
# EPOCH = 276, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 277, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 278, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 279, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 280, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 281, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 282, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 283, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 284, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 285, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 286, LOSS=0.0609
# Saved at ./save/test.ckpt
# EPOCH = 287, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 288, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 289, LOSS=0.0610
# Saved at ./save/test.ckpt
# EPOCH = 290, LOSS=0.0609
# Saved at ./save/test.ckpt
# EPOCH = 291, LOSS=0.0609
# Saved at ./save/test.ckpt
# EPOCH = 292, LOSS=0.0609
# Saved at ./save/test.ckpt
# EPOCH = 293, LOSS=0.0609
# Saved at ./save/test.ckpt
# EPOCH = 294, LOSS=0.0608
# Saved at ./save/test.ckpt
# EPOCH = 295, LOSS=0.0608
# Saved at ./save/test.ckpt
# EPOCH = 296, LOSS=0.0607
# Saved at ./save/test.ckpt
# EPOCH = 297, LOSS=0.0607
# Saved at ./save/test.ckpt
# EPOCH = 298, LOSS=0.0607
# Saved at ./save/test.ckpt
# EPOCH = 299, LOSS=0.0607
# Saved at ./save/test.ckpt
# EPOCH = 300, LOSS=0.0607
# Saved at ./save/test.ckpt
# EPOCH = 301, LOSS=0.0606
# Saved at ./save/test.ckpt
# EPOCH = 302, LOSS=0.0606
# Saved at ./save/test.ckpt
# EPOCH = 303, LOSS=0.0606
# Saved at ./save/test.ckpt
# EPOCH = 304, LOSS=0.0606
# Saved at ./save/test.ckpt
# EPOCH = 305, LOSS=0.0605
# Saved at ./save/test.ckpt
# EPOCH = 306, LOSS=0.0605
# Saved at ./save/test.ckpt
# EPOCH = 307, LOSS=0.0605
# Saved at ./save/test.ckpt
# EPOCH = 308, LOSS=0.0605
# Saved at ./save/test.ckpt
# EPOCH = 309, LOSS=0.0605
# Saved at ./save/test.ckpt
# EPOCH = 310, LOSS=0.0604
# Saved at ./save/test.ckpt
# EPOCH = 311, LOSS=0.0604
# Saved at ./save/test.ckpt
# EPOCH = 312, LOSS=0.0604
# Saved at ./save/test.ckpt
# EPOCH = 313, LOSS=0.0604
# Saved at ./save/test.ckpt
# EPOCH = 314, LOSS=0.0604
# Saved at ./save/test.ckpt
# EPOCH = 315, LOSS=0.0604
# Saved at ./save/test.ckpt
# EPOCH = 316, LOSS=0.0603
# Saved at ./save/test.ckpt
# EPOCH = 317, LOSS=0.0603
# Saved at ./save/test.ckpt
# EPOCH = 318, LOSS=0.0603
# Saved at ./save/test.ckpt
# EPOCH = 319, LOSS=0.0603
# Saved at ./save/test.ckpt
# EPOCH = 320, LOSS=0.0602
# Saved at ./save/test.ckpt
# EPOCH = 321, LOSS=0.0602
# Saved at ./save/test.ckpt
# EPOCH = 322, LOSS=0.0602
# Saved at ./save/test.ckpt
# EPOCH = 323, LOSS=0.0602
# Saved at ./save/test.ckpt
# EPOCH = 324, LOSS=0.0602
# Saved at ./save/test.ckpt
# EPOCH = 325, LOSS=0.0601
# Saved at ./save/test.ckpt
# EPOCH = 326, LOSS=0.0601
# Saved at ./save/test.ckpt
# EPOCH = 327, LOSS=0.0601
# Saved at ./save/test.ckpt
# EPOCH = 328, LOSS=0.0601
# Saved at ./save/test.ckpt
# EPOCH = 329, LOSS=0.0601
# Saved at ./save/test.ckpt
# EPOCH = 330, LOSS=0.0600
# Saved at ./save/test.ckpt
# EPOCH = 331, LOSS=0.0600
# Saved at ./save/test.ckpt
# EPOCH = 332, LOSS=0.0600
# Saved at ./save/test.ckpt
# EPOCH = 333, LOSS=0.0600
# Saved at ./save/test.ckpt
# EPOCH = 334, LOSS=0.0599
# Saved at ./save/test.ckpt
# EPOCH = 335, LOSS=0.0599
# Saved at ./save/test.ckpt
# EPOCH = 336, LOSS=0.0599
# Saved at ./save/test.ckpt
# EPOCH = 337, LOSS=0.0599
# Saved at ./save/test.ckpt
# EPOCH = 338, LOSS=0.0599
# Saved at ./save/test.ckpt
# EPOCH = 339, LOSS=0.0599
# Saved at ./save/test.ckpt
# EPOCH = 340, LOSS=0.0598
# Saved at ./save/test.ckpt
# EPOCH = 341, LOSS=0.0598
# Saved at ./save/test.ckpt
# EPOCH = 342, LOSS=0.0598
# Saved at ./save/test.ckpt
# EPOCH = 343, LOSS=0.0598
# Saved at ./save/test.ckpt
# EPOCH = 344, LOSS=0.0597
# Saved at ./save/test.ckpt
# EPOCH = 345, LOSS=0.0597
# Saved at ./save/test.ckpt
# EPOCH = 346, LOSS=0.0597
# Saved at ./save/test.ckpt
# EPOCH = 347, LOSS=0.0597
# Saved at ./save/test.ckpt
# EPOCH = 348, LOSS=0.0597
# Saved at ./save/test.ckpt
# EPOCH = 349, LOSS=0.0596
# Saved at ./save/test.ckpt
# EPOCH = 350, LOSS=0.0596
# Saved at ./save/test.ckpt
# EPOCH = 351, LOSS=0.0595
# Saved at ./save/test.ckpt
# EPOCH = 352, LOSS=0.0596
# Saved at ./save/test.ckpt
# EPOCH = 353, LOSS=0.0596
# Saved at ./save/test.ckpt
# EPOCH = 354, LOSS=0.0596
# Saved at ./save/test.ckpt
# EPOCH = 355, LOSS=0.0595
# Saved at ./save/test.ckpt
# EPOCH = 356, LOSS=0.0595
# Saved at ./save/test.ckpt
# EPOCH = 357, LOSS=0.0594
# Saved at ./save/test.ckpt
# EPOCH = 358, LOSS=0.0594
# Saved at ./save/test.ckpt
# EPOCH = 359, LOSS=0.0594
# Saved at ./save/test.ckpt
# EPOCH = 360, LOSS=0.0593
# Saved at ./save/test.ckpt
# EPOCH = 361, LOSS=0.0593
# Saved at ./save/test.ckpt
# EPOCH = 362, LOSS=0.0593
# Saved at ./save/test.ckpt
# EPOCH = 363, LOSS=0.0593
# Saved at ./save/test.ckpt
# EPOCH = 364, LOSS=0.0593
# Saved at ./save/test.ckpt
# EPOCH = 365, LOSS=0.0595
# Saved at ./save/test.ckpt
# EPOCH = 366, LOSS=0.0596
# Saved at ./save/test.ckpt
# EPOCH = 367, LOSS=0.0595
# Saved at ./save/test.ckpt
# EPOCH = 368, LOSS=0.0593
# Saved at ./save/test.ckpt
# EPOCH = 369, LOSS=0.0592
# Saved at ./save/test.ckpt
# EPOCH = 370, LOSS=0.0592
# Saved at ./save/test.ckpt
# EPOCH = 371, LOSS=0.0593
# Saved at ./save/test.ckpt
# EPOCH = 372, LOSS=0.0593
# Saved at ./save/test.ckpt
# EPOCH = 373, LOSS=0.0592
# Saved at ./save/test.ckpt
# EPOCH = 374, LOSS=0.0591
# Saved at ./save/test.ckpt
# EPOCH = 375, LOSS=0.0591
# Saved at ./save/test.ckpt
# EPOCH = 376, LOSS=0.0591
# Saved at ./save/test.ckpt
# EPOCH = 377, LOSS=0.0591
# Saved at ./save/test.ckpt
# EPOCH = 378, LOSS=0.0591
# Saved at ./save/test.ckpt
# EPOCH = 379, LOSS=0.0590
# Saved at ./save/test.ckpt
# EPOCH = 380, LOSS=0.0590
# Saved at ./save/test.ckpt
# EPOCH = 381, LOSS=0.0590
# Saved at ./save/test.ckpt
# EPOCH = 382, LOSS=0.0590
# Saved at ./save/test.ckpt
# EPOCH = 383, LOSS=0.0590
# Saved at ./save/test.ckpt
# EPOCH = 384, LOSS=0.0589
# Saved at ./save/test.ckpt
# EPOCH = 385, LOSS=0.0589
# Saved at ./save/test.ckpt
# EPOCH = 386, LOSS=0.0589
# Saved at ./save/test.ckpt
# EPOCH = 387, LOSS=0.0589
# Saved at ./save/test.ckpt
# EPOCH = 388, LOSS=0.0589
# Saved at ./save/test.ckpt
# EPOCH = 389, LOSS=0.0589
# Saved at ./save/test.ckpt
# EPOCH = 390, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 391, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 392, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 393, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 394, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 395, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 396, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 397, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 398, LOSS=0.0588
# Saved at ./save/test.ckpt
# EPOCH = 399, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 400, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 401, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 402, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 403, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 404, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 405, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 406, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 407, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 408, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 409, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 410, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 411, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 412, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 413, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 414, LOSS=0.0585
# Saved at ./save/test.ckpt
# EPOCH = 415, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 416, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 417, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 418, LOSS=0.0589
# Saved at ./save/test.ckpt
# EPOCH = 419, LOSS=0.0591
# Saved at ./save/test.ckpt
# EPOCH = 420, LOSS=0.0590
# Saved at ./save/test.ckpt
# EPOCH = 421, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 422, LOSS=0.0585
# Saved at ./save/test.ckpt
# EPOCH = 423, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 424, LOSS=0.0589
# Saved at ./save/test.ckpt
# EPOCH = 425, LOSS=0.0587
# Saved at ./save/test.ckpt
# EPOCH = 426, LOSS=0.0584
# Saved at ./save/test.ckpt
# EPOCH = 427, LOSS=0.0585
# Saved at ./save/test.ckpt
# EPOCH = 428, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 429, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 430, LOSS=0.0584
# Saved at ./save/test.ckpt
# EPOCH = 431, LOSS=0.0584
# Saved at ./save/test.ckpt
# EPOCH = 432, LOSS=0.0586
# Saved at ./save/test.ckpt
# EPOCH = 433, LOSS=0.0585
# Saved at ./save/test.ckpt
# EPOCH = 434, LOSS=0.0584
# Saved at ./save/test.ckpt
# EPOCH = 435, LOSS=0.0584
# Saved at ./save/test.ckpt
# EPOCH = 436, LOSS=0.0584
# Saved at ./save/test.ckpt
# EPOCH = 437, LOSS=0.0584
# Saved at ./save/test.ckpt
# EPOCH = 438, LOSS=0.0583
# Saved at ./save/test.ckpt
# EPOCH = 439, LOSS=0.0583
# Saved at ./save/test.ckpt
# EPOCH = 440, LOSS=0.0583
# Saved at ./save/test.ckpt
# EPOCH = 441, LOSS=0.0583
# Saved at ./save/test.ckpt
# EPOCH = 442, LOSS=0.0582
# Saved at ./save/test.ckpt
# EPOCH = 443, LOSS=0.0582
# Saved at ./save/test.ckpt
# EPOCH = 444, LOSS=0.0582
# Saved at ./save/test.ckpt
# EPOCH = 445, LOSS=0.0583
# Saved at ./save/test.ckpt
# EPOCH = 446, LOSS=0.0582
# Saved at ./save/test.ckpt
# EPOCH = 447, LOSS=0.0582
# Saved at ./save/test.ckpt
# EPOCH = 448, LOSS=0.0582
# Saved at ./save/test.ckpt
# EPOCH = 449, LOSS=0.0582
# Saved at ./save/test.ckpt
# EPOCH = 450, LOSS=0.0582
# Saved at ./save/test.ckpt
# EPOCH = 451, LOSS=0.0581
# Saved at ./save/test.ckpt
# EPOCH = 452, LOSS=0.0581
# Saved at ./save/test.ckpt
# EPOCH = 453, LOSS=0.0581
# Saved at ./save/test.ckpt
# EPOCH = 454, LOSS=0.0581
# Saved at ./save/test.ckpt
# EPOCH = 455, LOSS=0.0580
# Saved at ./save/test.ckpt
# EPOCH = 456, LOSS=0.0581
# Saved at ./save/test.ckpt
# EPOCH = 457, LOSS=0.0581
# Saved at ./save/test.ckpt
# EPOCH = 458, LOSS=0.0580
# Saved at ./save/test.ckpt
# EPOCH = 459, LOSS=0.0580
# Saved at ./save/test.ckpt
# EPOCH = 460, LOSS=0.0580
# Saved at ./save/test.ckpt
# EPOCH = 461, LOSS=0.0580
# Saved at ./save/test.ckpt
# EPOCH = 462, LOSS=0.0579
# Saved at ./save/test.ckpt
# EPOCH = 463, LOSS=0.0579
# Saved at ./save/test.ckpt
# EPOCH = 464, LOSS=0.0579
# Saved at ./save/test.ckpt
# EPOCH = 465, LOSS=0.0580
# Saved at ./save/test.ckpt
# EPOCH = 466, LOSS=0.0580
# Saved at ./save/test.ckpt
# EPOCH = 467, LOSS=0.0579
# Saved at ./save/test.ckpt
# EPOCH = 468, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 469, LOSS=0.0579
# Saved at ./save/test.ckpt
# EPOCH = 470, LOSS=0.0580
# Saved at ./save/test.ckpt
# EPOCH = 471, LOSS=0.0579
# Saved at ./save/test.ckpt
# EPOCH = 472, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 473, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 474, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 475, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 476, LOSS=0.0579
# Saved at ./save/test.ckpt
# EPOCH = 477, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 478, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 479, LOSS=0.0577
# Saved at ./save/test.ckpt
# EPOCH = 480, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 481, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 482, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 483, LOSS=0.0577
# Saved at ./save/test.ckpt
# EPOCH = 484, LOSS=0.0578
# Saved at ./save/test.ckpt
# EPOCH = 485, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 486, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 487, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 488, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 489, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 490, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 491, LOSS=0.0577
# Saved at ./save/test.ckpt
# EPOCH = 492, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 493, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 494, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 495, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 496, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 497, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 498, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 499, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 500, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 501, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 502, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 503, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 504, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 505, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 506, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 507, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 508, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 509, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 510, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 511, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 512, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 513, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 514, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 515, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 516, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 517, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 518, LOSS=0.0575
# Saved at ./save/test.ckpt
# EPOCH = 519, LOSS=0.0576
# Saved at ./save/test.ckpt
# EPOCH = 520, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 521, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 522, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 523, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 524, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 525, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 526, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 527, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 528, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 529, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 530, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 531, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 532, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 533, LOSS=0.0574
# Saved at ./save/test.ckpt
# EPOCH = 534, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 535, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 536, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 537, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 538, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 539, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 540, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 541, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 542, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 543, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 544, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 545, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 546, LOSS=0.0573
# Saved at ./save/test.ckpt
# EPOCH = 547, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 548, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 549, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 550, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 551, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 552, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 553, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 554, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 555, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 556, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 557, LOSS=0.0572
# Saved at ./save/test.ckpt
# EPOCH = 558, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 559, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 560, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 561, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 562, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 563, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 564, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 565, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 566, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 567, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 568, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 569, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 570, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 571, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 572, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 573, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 574, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 575, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 576, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 577, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 578, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 579, LOSS=0.0571
# Saved at ./save/test.ckpt
# EPOCH = 580, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 581, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 582, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 583, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 584, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 585, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 586, LOSS=0.0570
# Saved at ./save/test.ckpt
# EPOCH = 587, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 588, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 589, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 590, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 591, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 592, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 593, LOSS=0.0569
# Saved at ./save/test.ckpt
# EPOCH = 594, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 595, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 596, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 597, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 598, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 599, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 600, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 601, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 602, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 603, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 604, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 605, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 606, LOSS=0.0568
# Saved at ./save/test.ckpt
# EPOCH = 607, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 608, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 609, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 610, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 611, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 612, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 613, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 614, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 615, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 616, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 617, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 618, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 619, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 620, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 621, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 622, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 623, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 624, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 625, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 626, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 627, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 628, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 629, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 630, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 631, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 632, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 633, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 634, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 635, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 636, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 637, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 638, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 639, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 640, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 641, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 642, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 643, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 644, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 645, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 646, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 647, LOSS=0.0567
# Saved at ./save/test.ckpt
# EPOCH = 648, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 649, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 650, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 651, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 652, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 653, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 654, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 655, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 656, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 657, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 658, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 659, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 660, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 661, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 662, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 663, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 664, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 665, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 666, LOSS=0.0566
# Saved at ./save/test.ckpt
# EPOCH = 667, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 668, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 669, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 670, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 671, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 672, LOSS=0.0565
# Saved at ./save/test.ckpt
# EPOCH = 673, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 674, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 675, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 676, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 677, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 678, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 679, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 680, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 681, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 682, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 683, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 684, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 685, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 686, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 687, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 688, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 689, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 690, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 691, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 692, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 693, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 694, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 695, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 696, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 697, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 698, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 699, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 700, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 701, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 702, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 703, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 704, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 705, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 706, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 707, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 708, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 709, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 710, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 711, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 712, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 713, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 714, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 715, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 716, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 717, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 718, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 719, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 720, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 721, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 722, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 723, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 724, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 725, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 726, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 727, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 728, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 729, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 730, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 731, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 732, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 733, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 734, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 735, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 736, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 737, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 738, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 739, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 740, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 741, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 742, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 743, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 744, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 745, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 746, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 747, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 748, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 749, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 750, LOSS=0.0564
# Saved at ./save/test.ckpt
# EPOCH = 751, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 752, LOSS=0.0563
# Saved at ./save/test.ckpt
# EPOCH = 753, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 754, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 755, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 756, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 757, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 758, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 759, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 760, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 761, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 762, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 763, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 764, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 765, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 766, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 767, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 768, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 769, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 770, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 771, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 772, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 773, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 774, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 775, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 776, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 777, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 778, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 779, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 780, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 781, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 782, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 783, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 784, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 785, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 786, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 787, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 788, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 789, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 790, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 791, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 792, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 793, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 794, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 795, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 796, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 797, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 798, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 799, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 800, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 801, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 802, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 803, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 804, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 805, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 806, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 807, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 808, LOSS=0.0562
# Saved at ./save/test.ckpt
# EPOCH = 809, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 810, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 811, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 812, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 813, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 814, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 815, LOSS=0.0561
# Saved at ./save/test.ckpt
# EPOCH = 816, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 817, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 818, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 819, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 820, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 821, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 822, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 823, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 824, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 825, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 826, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 827, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 828, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 829, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 830, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 831, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 832, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 833, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 834, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 835, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 836, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 837, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 838, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 839, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 840, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 841, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 842, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 843, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 844, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 845, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 846, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 847, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 848, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 849, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 850, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 851, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 852, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 853, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 854, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 855, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 856, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 857, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 858, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 859, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 860, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 861, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 862, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 863, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 864, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 865, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 866, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 867, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 868, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 869, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 870, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 871, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 872, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 873, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 874, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 875, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 876, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 877, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 878, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 879, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 880, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 881, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 882, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 883, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 884, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 885, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 886, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 887, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 888, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 889, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 890, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 891, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 892, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 893, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 894, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 895, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 896, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 897, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 898, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 899, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 900, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 901, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 902, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 903, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 904, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 905, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 906, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 907, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 908, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 909, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 910, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 911, LOSS=0.0560
# Saved at ./save/test.ckpt
# EPOCH = 912, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 913, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 914, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 915, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 916, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 917, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 918, LOSS=0.0559
# Saved at ./save/test.ckpt
# EPOCH = 919, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 920, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 921, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 922, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 923, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 924, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 925, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 926, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 927, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 928, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 929, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 930, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 931, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 932, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 933, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 934, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 935, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 936, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 937, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 938, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 939, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 940, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 941, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 942, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 943, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 944, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 945, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 946, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 947, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 948, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 949, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 950, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 951, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 952, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 953, LOSS=0.0558
# Saved at ./save/test.ckpt
# EPOCH = 954, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 955, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 956, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 957, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 958, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 959, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 960, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 961, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 962, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 963, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 964, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 965, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 966, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 967, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 968, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 969, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 970, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 971, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 972, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 973, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 974, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 975, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 976, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 977, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 978, LOSS=0.0557
# Saved at ./save/test.ckpt
# EPOCH = 979, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 980, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 981, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 982, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 983, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 984, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 985, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 986, LOSS=0.0555
# Saved at ./save/test.ckpt
# EPOCH = 987, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 988, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 989, LOSS=0.0555
# Saved at ./save/test.ckpt
# EPOCH = 990, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 991, LOSS=0.0555
# Saved at ./save/test.ckpt
# EPOCH = 992, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 993, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 994, LOSS=0.0555
# Saved at ./save/test.ckpt
# EPOCH = 995, LOSS=0.0556
# Saved at ./save/test.ckpt
# EPOCH = 996, LOSS=0.0555
# Saved at ./save/test.ckpt
# EPOCH = 997, LOSS=0.0555
# Saved at ./save/test.ckpt
# EPOCH = 998, LOSS=0.0555
# Saved at ./save/test.ckpt
# EPOCH = 999, LOSS=0.0555
# Saved at ./save/test.ckpt
