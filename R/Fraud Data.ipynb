# %%
library(pacman)

pacman::p_load(ranger, caret, data.table)

creditcard_data <- read.csv("data/creditcard.csv")

# %%
dim(creditcard_data)
# Out:
# [1] 284807     31

# %%
head(creditcard_data)
# Out:
#   Time V1         V2          V3        V4         V5          V6
# 1 0    -1.3598071 -0.07278117 2.5363467  1.3781552 -0.33832077  0.46238778
# 2 0     1.1918571  0.26615071 0.1664801  0.4481541  0.06001765 -0.08236081
# 3 1    -1.3583541 -1.34016307 1.7732093  0.3797796 -0.50319813  1.80049938
# 4 1    -0.9662717 -0.18522601 1.7929933 -0.8632913 -0.01030888  1.24720317
# 5 2    -1.1582331  0.87773675 1.5487178  0.4030339 -0.40719338  0.09592146
# 6 2    -0.4259659  0.96052304 1.1411093 -0.1682521  0.42098688 -0.02972755
#   V7          V8          V9         ... V21          V22          V23
# 1  0.23959855  0.09869790  0.3637870 ... -0.018306778  0.277837576 -0.11047391
# 2 -0.07880298  0.08510165 -0.2554251 ... -0.225775248 -0.638671953  0.10128802
# 3  0.79146096  0.24767579 -1.5146543 ...  0.247998153  0.771679402  0.90941226
# 4  0.23760894  0.37743587 -1.3870241 ... -0.108300452  0.005273597 -0.19032052
# ...

# %%
tail(creditcard_data, 6)
# Out:
#        Time   V1          V2          V3         V4         V5
# 284802 172785   0.1203164  0.93100513 -0.5460121 -0.7450968  1.13031398
# 284803 172786 -11.8811179 10.07178497 -9.8347835 -2.0666557 -5.36447278
# 284804 172787  -0.7327887 -0.05508049  2.0350297 -0.7385886  0.86822940
# 284805 172788   1.9195650 -0.30125385 -3.2496398 -0.5578281  2.63051512
# 284806 172788  -0.2404400  0.53048251  0.7025102  0.6897992 -0.37796113
# 284807 172792  -0.5334125 -0.18973334  0.7033374 -0.5062712 -0.01254568
#        V6         V7         V8         V9         ... V21        V22
# 284802 -0.2359732  0.8127221  0.1150929 -0.2040635 ... -0.3142046 -0.8085204
# 284803 -2.6068373 -4.9182154  7.3053340  1.9144283 ...  0.2134541  0.1118637
# 284804  1.0584153  0.0243297  0.2948687  0.5848000 ...  0.2142053  0.9243836
# 284805  3.0312601 -0.2968265  0.7084172  0.4324540 ...  0.2320450  0.5782290
# 284806  0.6237077 -0.6861800  0.6791455  0.3920867 ...  0.2652449  0.8000487
# ...

# %%
table(creditcard_data$Class)
# Out:
#      0      1
# 284315    492

# %%
summary(creditcard_data$Amount)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#     0.00     5.60    22.00    88.35    77.17 25691.16

# %%
names(creditcard_data)
# Out:
#  [1] "Time"   "V1"     "V2"     "V3"     "V4"     "V5"     "V6"     "V7"
#  [9] "V8"     "V9"     "V10"    "V11"    "V12"    "V13"    "V14"    "V15"
# [17] "V16"    "V17"    "V18"    "V19"    "V20"    "V21"    "V22"    "V23"
# [25] "V24"    "V25"    "V26"    "V27"    "V28"    "Amount" "Class"

# %%
var(creditcard_data$Amount)
# Out:
# [1] 62560.07

# %%
sd(creditcard_data$Amount)
# Out:
# [1] 250.1201

# %% [markdown]
# # Data standarizadization (scaling)

# %%
creditcard_data$Amount = scale(creditcard_data$Amount)
NewData=creditcard_data[,-c(1)]
head(NewData)
# Out:
#   V1         V2          V3        V4         V5          V6
# 1 -1.3598071 -0.07278117 2.5363467  1.3781552 -0.33832077  0.46238778
# 2  1.1918571  0.26615071 0.1664801  0.4481541  0.06001765 -0.08236081
# 3 -1.3583541 -1.34016307 1.7732093  0.3797796 -0.50319813  1.80049938
# 4 -0.9662717 -0.18522601 1.7929933 -0.8632913 -0.01030888  1.24720317
# 5 -1.1582331  0.87773675 1.5487178  0.4030339 -0.40719338  0.09592146
# 6 -0.4259659  0.96052304 1.1411093 -0.1682521  0.42098688 -0.02972755
#   V7          V8          V9         V10         ... V21          V22
# 1  0.23959855  0.09869790  0.3637870  0.09079417 ... -0.018306778  0.277837576
# 2 -0.07880298  0.08510165 -0.2554251 -0.16697441 ... -0.225775248 -0.638671953
# 3  0.79146096  0.24767579 -1.5146543  0.20764287 ...  0.247998153  0.771679402
# 4  0.23760894  0.37743587 -1.3870241 -0.05495192 ... -0.108300452  0.005273597
# 5  0.59294075 -0.27053268  0.8177393  0.75307443 ... -0.009430697  0.798278495
# ...

# %% [markdown]
# # Spliting dataset into training set.
# Split ratio 0.8.

# %%
# pacman::p_install(caTools)
library(caTools)
set.seed(123)
data_sample = sample.split(NewData$Class, SplitRatio=0.8)
train_data = subset(NewData, data_sample==TRUE)
test_data = subset(NewData, data_sample==FALSE)
dim(train_data)
dim(test_data)
# Out:
# [1] 227846     30
# [1] 56961    30

# %% [markdown]
# # Fitting Logistic Regression Model

# %%
Logistic_Model = glm(Class~.,test_data,family=binomial())
# Out:
# Warning message:
# "glm.fit: fitted probabilities numerically 0 or 1 occurred"

# %%
summary(Logistic_Model)
# Out:
# Call:
# glm(formula = Class ~ ., family = binomial(), data = test_data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -4.9019  -0.0254  -0.0156  -0.0078   4.0877
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -12.52800   10.30537  -1.216   0.2241
# V1           -0.17299    1.27381  -0.136   0.8920
# V2            1.44512    4.23062   0.342   0.7327
# V3            0.17897    0.24058   0.744   0.4569
# V4            3.13593    7.17768   0.437   0.6622
# V5            1.49014    3.80369   0.392   0.6952
# V6           -0.12428    0.22202  -0.560   0.5756
# V7            1.40903    4.22644   0.333   0.7388
# V8           -0.35254    0.17462  -2.019   0.0435 *
# V9            3.02176    8.67262   0.348   0.7275
# V10          -2.89571    6.62383  -0.437   0.6620
# V11          -0.09769    0.28270  -0.346   0.7297
# V12           1.97992    6.56699   0.301   0.7630
# V13          -0.71674    1.25649  -0.570   0.5684
# ...

# %%
plot(Logistic_Model)
# Out:
# Plot with title ""
# Plot with title ""
# Warning message in sqrt(crit * p * (1 - hh)/hh):
# "wyprodukowano wartości NaN"
# Warning message in sqrt(crit * p * (1 - hh)/hh):
# "wyprodukowano wartości NaN"
# Plot with title ""
# Plot with title ""

# %% [markdown]
# Aby ocenić wydajność naszego modelu, nakreślimy krzywą ROC. ROC jest również znany jako Optymistyczna charakterystyka odbiornika. W tym celu najpierw zaimportujemy pakiet ROC, a następnie wykreślimy naszą krzywą ROC, aby przeanalizować jego wydajność.

# %%
# pacman::p_install(pROC)
library(pROC)
lr.predict <-  predict(Logistic_Model, train_data, probability = TRUE)
auc.gmb = roc(test_data$Class, lr.predict, plot=TRUE, col="blue")
# Out:
# Setting levels: control = 0, case = 1
# Error in roc.default(test_data$Class, lr.predict, plot = TRUE, col = "blue"): Response and predictor must be vectors of the same length.
# Traceback:
#
# 1. roc(test_data$Class, lr.predict, plot = TRUE, col = "blue")
# 2. roc.default(test_data$Class, lr.predict, plot = TRUE, col = "blue")
# 3. stop("Response and predictor must be vectors of the same length.")

# %% [markdown]
# # Fitting a Decision Tree Model
# The plotted outcomes are a consequence through which we can conclude as to what class the object belongs to.

# %%
library(rpart)
# library(rpart.plot)
decisionTree_model  <- rpart(Class ~ . , creditcard_data, method = "class")
predicted_val <- predict(decisionTree_model, creditcard_data, type="class")
probability <- predict(decisionTree_model, creditcard_data, type = "prob")

# %%
# pacman::p_load(rpart.plot)
rpart.plot(decisionTree_model)
# Out:
# plot without title

# %% [markdown]
# # Artificial Neural Network
# ANN models are able to learn the patterns using the historical data and are able to perform classification on the input data.

# %%
pacman::p_load(neuralnet)
ANN_model = neuralnet(Class~.,train_data, linear.output=FALSE)
plot(ANN_model)
# Out:
# also installing the dependency 'Deriv'
#
#
# Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/4.0:
#   nie można otworzyć adresu URL 'http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/4.0/PACKAGES'"
# package 'Deriv' successfully unpacked and MD5 sums checked
# package 'neuralnet' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Weronika\AppData\Local\Temp\Rtmp63Hy9W\downloaded_packages
# neuralnet installed

# %% [markdown]
# Thresholding the data. Values above 0.5 will correspond to 1, and the rest will be 0.

# %%
predANN = compute(ANN_model, test_data)
resultANN = predANN$net.result
resultANN=ifelse(resultANN>0.5, 1, 0)

# %% [markdown]
# # Gradient Boosting (GBM)
# Gradient Boosting is a popular machine learning algorithm, that is used to perform classification and regression tasks. This model comprises of several underlying ensemble models like weak decision trees. These decision trees combine together to form a strong model of gradient boosting.

# %%
library(gbm, quietly=TRUE)

system.time(
    model_gbm <- gbm(Class ~ ., distribution = "bernoulli",
                    data = rbind(train_data, test_data),
                    n.trees = 500, interaction.depth = 3,
                    n.minobsinnode = 100, shrinkage = 0.01,
                    bag.fraction = 0.5, 
                    train.fraction = nrow(train_data) / (nrow(train_data) + nrow(test_data))))

gbm.iter = gbm.perf(model_gbm, method = "test")

# %%
model.influence = relative.influence(model_gbm, n.trees = gbm.iter, sort. = TRUE)

plot(model_gbm)

# %%
gbm_test = predict(model_gbm, newdata==test_data, n.trees = gbm.iter)
gbm_auc = roc(test_data$Class, gbm_test, plot = TRUE, col = "red")

# %%
print(gbm_auc)
