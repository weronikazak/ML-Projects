# %%
import tensorflow as tf
import numpy as np
import os

# %%
daily_sales_numbers = [21, 22, -108, 31, -1, 32, 34, 31]

tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_numbers)
tf_dataset
# Out:
# <TensorSliceDataset shapes: (), types: tf.int32>

# %% [markdown]
# ### Iterate through tf dataset

# %%
for sales in tf_dataset:
    print(sales.numpy())
# Out:
# 21
# 22
# -108
# 31
# -1
# 32
# 34
# 31

# %% [markdown]
# ### Iterate through elements as numpy elements

# %%
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 21
# 22
# -108
# 31
# -1
# 32
# 34
# 31

# %% [markdown]
# ### Iterate through first n elements in dataset

# %%
for sales in tf_dataset.take(3):
    print(sales.numpy())
# Out:
# 21
# 22
# -108

# %% [markdown]
# ### Filter sales numbers that are < 0

# %%
tf_dataset = tf_dataset.filter(lambda x: x > 0)
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 21
# 22
# 31
# 32
# 34
# 31

# %% [markdown]
# ### Convert sales from USA dollars to PLN

# %%
tf_dataset = tf_dataset.map(lambda x: float(x) * 3.72)
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 78.12
# 81.840004
# 115.32
# 119.04
# 126.48
# 115.32

# %% [markdown]
# ### Shuffle

# %%
tf_dataset = tf_dataset.shuffle(2)
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 78.12
# 81.840004
# 115.32
# 119.04
# 126.48
# 115.32

# %% [markdown]
# ### Batching

# %%
for sales_batch in tf_dataset.batch(2):
    print(sales_batch.numpy())
# Out:
# [78.12     81.840004]
# [115.32 119.04]
# [115.32 126.48]

# %% [markdown]
# ## All of the above in one shot

# %%
tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_numbers)

tf_dataset = tf_dataset.filter(lambda x: x > 0).map(lambda y: float(y) * 3.72).shuffle(2).batch(2)

# %%
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# [ 78.12 115.32]
# [ 81.840004 126.48    ]
# [115.32 119.04]

# %% [markdown]
# ### Images

# %%
img_ds = tf.data.Dataset.list_files("train/*/*", shuffle=False)

# %%
img_count = len(img_ds)
img_count
# Out:
# 25000

# %%
type(img_ds)
# Out:
# tensorflow.python.data.ops.dataset_ops.TensorSliceDataset

# %%
for file in img_ds.take(3):
    print(file.numpy())
# Out:
# b'train\\cat\\cat.0.jpg'
# b'train\\cat\\cat.1.jpg'
# b'train\\cat\\cat.10.jpg'

# %%
class_names = ["cat", "dog"]

# %%
train_size = int(img_count*0.8)
train_ds = img_ds.take(train_size)
test_ds = img_ds.skip(train_size)

# %%
len(train_ds)
# Out:
# 20000

# %%
len(test_ds)
# Out:
# 5000

# %%
def get_label(file_path):
    import os
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2]

# %%
get_label("train\\dog\\dog.14.jpg")
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'dog'>

# %%
def process_img(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img)
    img = tf.image.resize(img, [128, 128])
    return img, label

# %%
img, label = process_img("train\\dog\\dog.14.jpg")
img.numpy()[:2]
# Out:
# array([[[ 84.529785,  92.533325,  94.522705],
#         [ 86.16284 ,  92.15723 ,  92.15442 ],
#         [ 95.680664,  99.149414,  97.618164],
#         [110.57495 , 112.39661 , 109.03992 ],
#         [114.18213 , 114.18213 , 114.18213 ],
#         [ 87.11804 ,  87.11804 ,  87.11804 ],
#         [112.680786, 112.680786, 112.680786],
#         [112.46716 , 112.46716 , 112.46716 ],
#         [137.9303  , 137.9303  , 137.9303  ],
#         [125.98877 , 125.98877 , 125.98877 ],
#         [137.55872 , 137.55872 , 137.55872 ],
#         [139.37048 , 139.37048 , 139.37048 ],
#         [145.98499 , 146.31311 , 143.32874 ],
#         [138.6576  , 139.6576  , 134.6576  ],
#         [117.03027 , 118.03027 , 113.03027 ],
#         [134.07068 , 135.07068 , 130.07068 ],
#         [136.80383 , 136.85071 , 136.61633 ],
#         [134.86047 , 134.86047 , 134.86047 ],
#         [128.52527 , 128.52527 , 128.52527 ],
#         [139.95557 , 139.95557 , 139.95557 ],
#         [137.44568 , 136.86755 , 134.86755 ],
#         [142.57031 , 141.57031 , 137.57031 ],
#         [130.38013 , 129.38013 , 125.38013 ],
#         [137.84521 , 136.84521 , 132.84521 ],
#         [136.77979 , 135.77979 , 131.77979 ],
#         [139.1554  , 138.1554  , 134.1554  ],
#         [149.03003 , 148.03003 , 144.03003 ],
#         [142.85095 , 141.85095 , 137.85095 ],
#         [144.51807 , 143.51807 , 139.51807 ],
#         [155.78174 , 154.78174 , 150.78174 ],
#         [145.83838 , 144.83838 , 140.83838 ],
#         [139.04407 , 138.04407 , 134.04407 ],
#         [139.24341 , 138.24341 , 134.24341 ],
#         [146.74341 , 145.74341 , 141.74341 ],
#         [142.21094 , 141.21094 , 137.21094 ],
#         [152.49268 , 151.49268 , 147.49268 ],
#         [137.41821 , 136.41821 , 132.41821 ],
#         [145.12451 , 144.12451 , 140.12451 ],
#         [148.50085 , 147.50085 , 143.50085 ],
#         [150.52344 , 149.52344 , 145.52344 ],
#         [138.28271 , 137.28271 , 133.28271 ],
#         [142.07678 , 141.07678 , 137.07678 ],
#         [148.35486 , 147.35486 , 143.35486 ],
#         [134.37793 , 133.37793 , 129.37793 ],
#         [160.46875 , 159.46875 , 155.46875 ],
#         [155.03174 , 154.03174 , 150.03174 ],
#         [154.70435 , 153.70435 , 149.70435 ],
#         [139.47693 , 138.47693 , 134.47693 ],
#         [144.37048 , 143.37048 , 139.37048 ],
#         [156.61377 , 155.61377 , 151.61377 ],
#         [156.1029  , 155.1029  , 151.1029  ],
#         [153.65869 , 152.65869 , 148.65869 ],
#         [161.29077 , 160.29077 , 156.29077 ],
#         [153.85205 , 152.85205 , 148.85205 ],
#         [192.81287 , 191.81287 , 187.81287 ],
#         [155.46985 , 154.46985 , 150.46985 ],
#         [175.23145 , 174.23145 , 170.23145 ],
#         [150.80725 , 149.80725 , 144.80725 ],
#         [154.01697 , 153.01697 , 148.01697 ],
#         [153.92249 , 157.92249 , 158.92249 ],
#         [151.03125 , 155.03125 , 156.03125 ],
#         [167.40833 , 171.40833 , 172.40833 ],
#         [141.35803 , 145.35803 , 146.35803 ],
#         [156.79553 , 160.79553 , 161.79553 ],
#         [146.56519 , 150.56519 , 151.56519 ],
#         [151.89062 , 155.89062 , 156.89062 ],
#         [149.3418  , 153.3418  , 154.3418  ],
#         [137.28772 , 141.28772 , 142.28772 ],
#         [140.11218 , 144.11218 , 147.11218 ],
#         [136.31201 , 140.31201 , 143.31201 ],
#         [133.40173 , 137.40173 , 140.40173 ],
#         [137.99463 , 141.99463 , 144.99463 ],
#         [144.48499 , 148.48499 , 151.48499 ]]], dtype=float32)

# %%
train_ds = train_ds.map(process_img)
test_ds = test_ds.map(process_img)

# %%
for image, label in train_ds.take(1):
    print("****",image)
    print("****",label)
# Out:
# **** tf.Tensor(
# [[[203.45312  164.45312   87.453125]
#   [208.35938  169.35938   92.359375]
#   [209.26562  170.26562   93.265625]
#   ...
#   [245.26562  207.26562  124.265625]
#   [243.97498  203.97498  118.974976]
#   [239.45312  201.45312  120.453125]]
#
#  [[203.45312  164.45312   87.453125]
#   [208.35938  169.35938   92.359375]
#   [209.26562  170.26562   93.265625]
#   ...
#   [245.35168  208.91394  125.796875]
#   [243.39233  205.24219  122.00781 ]
#   [240.45312  202.45312  121.453125]]
#
#  [[203.45312  164.45312   87.453125]
#   [208.35938  169.35938   92.359375]
#   [209.26562  170.26562   93.265625]
#   ...
#   [246.       209.53125  129.07031 ]
#   [243.92981  206.28918  124.007935]
#   [241.45312  203.45312  122.453125]]
#
#  ...
#
#  [[156.45312  124.25781   51.648438]
#   [158.28918  126.09387   53.484497]
#   [159.21375  127.01843   54.409058]
#   ...
#   [  3.         4.         0.      ]
#   [  3.         4.         0.      ]
#   [  1.         2.         0.      ]]
#
#  [[153.88281  122.88281   55.882812]
#   [155.88281  124.88281   57.882812]
#   [157.91394  126.91394   59.91394 ]
#   ...
#   [  2.         3.         0.      ]
#   [  2.         3.         0.      ]
#   [  2.         3.         0.      ]]
#
#  [[151.41406  120.41406   53.414062]
#   [152.96094  121.96094   54.960938]
#   [156.25525  125.25525   58.25525 ]
#   ...
#   [  1.         2.         0.      ]
#   [  1.         2.         0.      ]
#   [  1.         2.         0.      ]]], shape=(128, 128, 3), dtype=float32)
# **** tf.Tensor(b'cat', shape=(), dtype=string)

# %%
def scale(image, label):
    return image/255, label

# %%
train_ds = train_ds.map(scale)

# %%
for image, label in train_ds.take(5):
    print("****Image: ",image.numpy()[0][0])
    print("****Label: ",label.numpy())
# Out:
# ****Image:  [0.7978554  0.6449142  0.34295344]
# ****Label:  b'cat'
# ****Image:  [0.14849687 0.17594784 0.14849687]
# ****Label:  b'cat'
# ****Image:  [0.10955637 0.13700736 0.16485661]
# ****Label:  b'cat'
# ****Image:  [0.8671957 0.8711173 0.8475879]
# ****Label:  b'cat'
# ****Image:  [0.54707414 0.4373255  0.29222748]
# ****Label:  b'cat'
